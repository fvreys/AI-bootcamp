# %% [markdown]
# <a href="https://colab.research.google.com/github/fvreys/AI-bootcamp/blob/main/notebooks/HTTP_async.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## HTTP requests and APIs

# %% [markdown]
# Let's make a request to [JSONPlaceholder](https://jsonplaceholder.typicode.com/), a free fake API for testing:

# %%
import requests

url = "https://jsonplaceholder.typicode.com/posts/1"
response = requests.get(url)

print(f"Status Code: {response.status_code}")

# %% [markdown]
# The response object contains everything about the server's reply. Here are the 4 most important attributes:

# %%
print(f"Status Code: {response.status_code}")
print(f"JSON Response: {response.json()}")
print(f"Text Response: {response.text}")
print(f"Headers: {response.headers}")

# %%
# Fetch multiple posts
response = requests.get("https://jsonplaceholder.typicode.com/posts")

if response.status_code == 200:
    posts = response.json()  # This is now a list of dictionaries
    print(f"Fetched {len(posts)} posts")

    first_post = posts[0]
    print(f"Title: {first_post['title']}")
else:
    print(f"Request failed with status: {response.status_code}")

# %% [markdown]
# ## HTTP methods and parameters

# %% [markdown]
# ### GET with query parameters
#
# Query parameters let you filter, search, or customize your requests. They appear after the `?` in URLs.

# %%
# Build the URL manually (not recommended)
url = "https://jsonplaceholder.typicode.com/posts?userId=1&_limit=5"
response = requests.get(url)

# Better: use the `params` argument
url = "https://jsonplaceholder.typicode.com/posts"
params = {
    'userId': 1,
    '_limit': 5
}

response = requests.get(url, params=params)
print(f"Final URL: {response.url}")  # See what was actually requested
print(f"Found {len(response.json())} posts")

# %%
response = requests.get("https://jsonplaceholder.typicode.com/users/1")
user = response.json()

# Bracket notation access (will raise KeyError if a key is missing)
print(f"City: {user['address']['city']}")

# Using .get() with a default value - safe for deep nesting
lat = user.get('address', {}).get('geo', {}).get('lat', 'Unknown')
lng = user.get('address', {}).get('geo', {}).get('lng', 'Unknown')

print(f"Latitude: {lat}")  # None if any key is missing
print(f"Longitude: {lng}")

# %%
response = requests.get("https://jsonplaceholder.typicode.com/posts")
posts = response.json()

# Extract specific fields from all posts
titles = [post['title'] for post in posts]
print(f"First 3 titles: {titles[:3]}")

# Filter by condition
user_1_posts = [post for post in posts if post['userId'] == 1]
print(f"User 1 has {len(user_1_posts)} posts")

# Extract nested data from a list
response = requests.get("https://jsonplaceholder.typicode.com/users")
users = response.json()

cities = [user['address']['city'] for user in users]
print(f"Cities: {cities}")

# %%
# with statement allows to set headers once, use for all requests
with requests.Session() as session:
    session.headers.update({
        'User-Agent': 'My App/1.0',
        'Accept': 'application/json'
    })

    # All requests in this session use these headers
    response1 = session.get("https://jsonplaceholder.typicode.com/posts/1")
    response2 = session.get("https://jsonplaceholder.typicode.com/users/1")

    print(f"Post: {response1.json()['title']}")
    print(f"User: {response2.json()['name']}")

# %% [markdown]
# Context managers (`with` statement) automatically handle resource cleanup. When you use with `requests.Session()`, Python creates a session object, lets you use it for multiple requests, and automatically closes it when done — even if an error occurs.
#
# Sessions reuse TCP connections between requests instead of creating new ones each time, which is faster. You can also set headers, cookies, or authentication once and they'll apply to all requests. When the `with` block ends, the session closes automatically.

# %% [markdown]
# ### POST - Creating resources
#
# POST requests send data to the server to create new resources. Use the `json` parameter to automatically serialize Python dictionaries.

# %%
url = "https://jsonplaceholder.typicode.com/posts"

new_post = {
    'title': 'My New Post',
    'body': 'This is the content of my post',
    'userId': 1
}

try:
    response = requests.post(url, json=new_post, timeout=5)
    response.raise_for_status()  # Raises HTTPError for bad status codes

    created_post = response.json()
    print(f"Status: {response.status_code}")  # 201 = Created
    print(f"Created post with ID: {created_post['id']}")

except requests.exceptions.HTTPError as e:
    print(f"HTTP Error: {e}")

# %% [markdown]
# **What happens here:**
# - The `json` parameter automatically converts your dict to JSON
# - Sets the `Content-Type: application/json` header
#
# The `try` block contains code that might fail. If an error occurs, Python jumps to the matching except block instead of crashing. This lets you handle errors gracefully and provide feedback to users.
# You can catch specific exceptions (like `HTTPError` above) or use multiple except blocks to handle different error types differently. Try to avoid using bare
# ```python
# except Exception as e
# ```
# it catches everything and tends to be harder to debug.

# %%
# For form-encoded data (like HTML forms)
form_data = {
    'username': 'john',
    'email': 'john@example.com'
}

response = requests.post(url, data=form_data)  # Use 'data' instead of 'json'

# %% [markdown]
# ### PUT - Full updates (replacing entire resource)
#
# PUT replaces the entire resource with your new data.

# %%
url = "https://jsonplaceholder.typicode.com/posts/1"

updated_post = {
    'id': 1,
    'title': 'Updated Title',
    'body': 'Completely new content',
    'userId': 1
}

response = requests.put(url, json=updated_post)

print(f"Status: {response.status_code}")
print(response.json())

# %% [markdown]
# ### PATCH - Partial updates (changing specific fields)
#
# PATCH updates only the fields you specify, leaving others unchanged.

# %%
url = "https://jsonplaceholder.typicode.com/posts/1"

partial_update = {
    'title': 'Just changing the title'
}

response = requests.patch(url, json=partial_update)

print(f"Status: {response.status_code}")
updated = response.json()
print(f"New title: {updated['title']}")
print(f"Body unchanged: {updated['body']}")  # Original body remains

# %% [markdown]
# **PUT vs PATCH:**
# - **PUT**: "Replace everything with this" (send all fields)
# - **PATCH**: "Just update these specific fields" (send only what changes)

# %% [markdown]
# ### DELETE - Removing resources

# %%
url = "https://jsonplaceholder.typicode.com/posts/1"

response = requests.delete(url)

print(f"Status: {response.status_code}")  # 200 or 204 (No Content)
print("Post deleted successfully" if response.status_code in [200, 204] else "Failed")

# %% [markdown]
# ### The basic pattern: `requests.METHOD(url, **kwargs)`

# %%
# Common keyword arguments (kwargs) across all methods:
response = requests.get(url, params={'key': 'value'})      # Query parameters
response = requests.post(url, json={'key': 'value'})       # JSON body
response = requests.put(url, json={'key': 'value'})        # JSON body
response = requests.patch(url, json={'key': 'value'})      # JSON body
response = requests.delete(url)                             # Usually no body

# Other useful keyword arguments (work with any method):
response = requests.get(
    url,
    headers={'Authorization': 'Bearer token123'},  # Custom headers
    timeout=5,                                      # Timeout in seconds
    params={'filter': 'active'}                     # Query params
)

# %% [markdown]
# ##  Headers and Authentication

# %% [markdown]
# Before discussing authentication, we have to mention managing sensitive credentials. This is done using `.env` files with the `python-dotenv` library. Never hardcode API keys or tokens directly in your code. Don't forget to add `.env` files to `.gitignore` (this is already present in this repository [since it uses the official Python `.gitignore`](https://github.com/github/gitignore/blob/fc6ce5da28a8c3480cc8a5acad050449f72a9261/Python.gitignore#L150), but if you create `.env.dev`, `.env.prod`, or something similar, don't forget to wildcard them or add them to the `.gitignore` explicitly).

# %% [markdown]
# Let's use the GitHub API to fetch public information about your starred repositories and your user profile. This doesn't modify anything.
#
# To proceed with this notebook, get a GitHub token:
#
# 1. Go to GitHub Settings → Developer settings → Personal access tokens → Tokens (classic)
# 2. Click "Generate new token (classic)"
# 3. Give it a name like "Requests tutorial"
# 4. Select no scopes or just public_repo (read-only access to public repos)
# 5. Copy the `.env.template` to a `.env` file:
# ```shell
# cp .env.template .env
# ```
# 6. Generate and copy the token to the created `.env` file

# %%
import os
import warnings
from dotenv import load_dotenv
import requests

load_dotenv('/workspace/.env', override=True)
github_token = os.getenv('GITHUB_TOKEN')

if not github_token or github_token == '<your-gh-api-token>':
    warnings.warn(
        "GITHUB_TOKEN is not set in your .env file!\n"
        "Please copy .env.template to .env and add your GitHub API token.",
        UserWarning,
        stacklevel=2
    )

# %%
# GitHub API endpoint
url = "https://api.github.com/user"

headers = {
    'Authorization': f'Bearer {github_token}',     # Authentication
    'Accept': 'application/vnd.github.v3+json',   # Expected response format
    'Content-Type': 'application/json'            # Format of data you're sending
}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    user = response.json()
    print(f"Username: {user['login']}")
    print(f"Name: {user['name']}")
    print(f"Public repos: {user['public_repos']}")
    print(f"Followers: {user['followers']}")
else:
    print(f"Error: {response.status_code}")

# %% [markdown]
# You can see exactly what headers were sent with your request:

# %%
# View the headers you actually sent
print("Headers sent with request:")
print("=" * 60)
for key, value in response.request.headers.items():
    # Mask sensitive data
    if key == 'Authorization':
        print(f"{key}: Bearer ***hidden***")
    else:
        print(f"{key}: {value}")

# %% [markdown]
# The server sends back headers:

# %%
print("Response headers:")
print("=" * 60)

# Access specific headers
print(f"Content-Type: {response.headers.get('Content-Type')}")
print(f"Server: {response.headers.get('Server', 'Unknown')}")
print(f"Status: {response.status_code}")

# GitHub-specific rate limit headers
print("\nGitHub Rate Limit Info:")
print(f"Limit: {response.headers.get('X-RateLimit-Limit')}")
print(f"Remaining: {response.headers.get('X-RateLimit-Remaining')}")
print(f"Reset: {response.headers.get('X-RateLimit-Reset')}")

# View all response headers
print("\nAll response headers:")
for key, value in response.headers.items():
    print(f"{key}: {value}")

# %% [markdown]
# HTTP headers are case-insensitive, but `requests` handles this automatically.

# %% [markdown]
# ## Introduction to async Python

# %% [markdown]
# ### Why async?

# %% [markdown]
# When you make HTTP requests synchronously, your program sits idle waiting for responses. This is called "blocking I/O." With async, you can start multiple requests and let them run concurrently. While waiting for one response, you can start other requests.
#
# ```
# Request 1 → Wait ──┐
# Request 2 → Wait ──┤
# Request 3 → Wait ──┼→ All responses come back around the same time
# Request 4 → Wait ──┤
# Request 5 → Wait ──┘
# ```

# %% [markdown]
# ### Async basics

# %% [markdown]
#  `async def` defines an async function:

# %%
# Regular function
def fetch_data():
    return requests.get(url)

# Async function
async def fetch_data():
    return await session.get(url)

# %% [markdown]
# Functions defined with `async def` return coroutines that must be awaited. `await` waits for async operations to complete:

# %%
async def get_user(session, username):
    response = await session.get(f"https://api.github.com/users/{username}")
    data = await response.json()  # await here also
    return data

# %% [markdown]
# Use `await` before any async operation (network calls, file I/O, etc.). Without `await`, you get a coroutine object instead of the actual result:

# %%
import aiohttp
import asyncio
import time

async def get_username(session):
    async with session.get("https://api.github.com/users/torvalds") as response:
        data = response.json()  # <- missing await
        return data

async def main():
    async with aiohttp.ClientSession() as session:
        result = await get_username(session)
        print(result)  # Prints: <coroutine object ClientResponse.json at 0x...>

await main()

# %% [markdown]
# If you see `<coroutine object <name> at 0x...>` (alongside the warning), the `await` is missing:

# %%
async def get_username(session):
    async with session.get("https://api.github.com/users/torvalds") as response:
        data = await response.json() # <- added the await
        return data

async def main():
    async with aiohttp.ClientSession() as session:
        result = await get_username(session)
        print(result)  # Prints: <coroutine object ClientResponse.json at 0x...>

await main()

# %% [markdown]
# Jupyter runs an event loop in the background automatically, so we use `await` to call async code from async code. Use `asyncio.run()` to start async code from sync code (regular Python scripts):

# %% [markdown]
# ```python
# # If you execute this in a code cell, you'll get the following:
# # RuntimeError: asyncio.run() cannot be called from a running event loop
# async def main():
#     async with aiohttp.ClientSession() as session:
#         user = await get_user(session, "torvalds")
#         print(user['name'])
#
# asyncio.run(main())
# ```

# %% [markdown]
# `asyncio.run()` vs `await`
#
# | Feature | `asyncio.run()` | `await` |
# |---------|----------------|---------|
# | **Event loop** | Creates and closes a new event loop | Uses an existing event loop |
# | **Where to use** | Regular Python scripts (no loop exists) | Inside async functions |
# | **Usage frequency** | Once per script (from sync code) | Multiple times (from async code) |
# | **Resource cleanup** | Cleans up resources when done | Doesn't create or close the loop |

# %% [markdown]
# The code below fetches 5 GitHub user profiles at the same time, showing how async works in practice.
# Note on `asyncio.gather()`: This runs multiple tasks concurrently and waits for all of them to finish. Results come back in the same order you passed them in.

# %%
urls = [
    "https://api.github.com/users/torvalds",
    "https://api.github.com/users/gvanrossum",
    "https://api.github.com/users/kennethreitz",
    "https://api.github.com/users/django",
    "https://api.github.com/users/pallets"
]

async def fetch_user(session, url):
    """Fetch a single user profile"""
    async with session.get(url) as response:
        user = await response.json()
        return user

async def fetch_all_users():
    """Fetch all users concurrently"""
    print("Fetching user profiles asynchronously...\n")
    start = time.time()

    async with aiohttp.ClientSession() as session: #  requests.Session() persists auth across requests
        # Create tasks for all requests
        tasks = [fetch_user(session, url) for url in urls]

        # Run all tasks concurrently
        users = await asyncio.gather(*tasks)

        for user in users:
            print(f"✓ Fetched {user['login']} - {user['public_repos']} repos")

    elapsed = time.time() - start
    print(f"\nTotal time: {elapsed:.2f} seconds")

await fetch_all_users()

# %% [markdown]
# ### Rate limiting

# %% [markdown]
# Most APIs limit how many requests you can make per hour. GitHub allows 60 requests/hour without authentication, or 5,000/hour with a token. Since async code fires off requests simultaneously, you can exhaust your quota in seconds. To avoid this, monitor rate limit headers and either space out your requests or handle rate limit errors when they happen:

# %%
import aiohttp
import asyncio
from datetime import datetime

async def fetch_repos_safely(session, username, headers):
    """Fetch repos with full rate limit handling"""
    url = f"https://api.github.com/users/{username}/repos"

    async with session.get(url, headers=headers) as response:
        # Check rate limits
        remaining = int(response.headers.get('X-RateLimit-Remaining', 0))
        limit = response.headers.get('X-RateLimit-Limit')
        reset_timestamp = int(response.headers.get('X-RateLimit-Reset', 0))

        print(f"Fetching {username}'s repos | Rate limit: {remaining}/{limit}")

        # Handle rate limit
        if response.status == 429:
            reset_time = datetime.fromtimestamp(reset_timestamp)
            wait_seconds = (reset_time - datetime.now()).total_seconds()
            print(f"Rate limited! Waiting {wait_seconds:.0f} seconds...")
            await asyncio.sleep(wait_seconds)
            return await fetch_repos_safely(session, username, headers)

        # Warn if running low
        if remaining < 10:
            reset_time = datetime.fromtimestamp(reset_timestamp)
            print(f"Only {remaining} requests left! Resets at {reset_time}")

        response.raise_for_status()
        return await response.json()

async def main():
    headers = {
        'Authorization': f'Bearer {github_token}',
        'Accept': 'application/vnd.github.v3+json'
    }

    usernames = ["torvalds", "gvanrossum", "kennethreitz"]

    async with aiohttp.ClientSession() as session:
        # Create all tasks at once
        tasks = [fetch_repos_safely(session, username, headers) for username in usernames]

        # Run them concurrently
        results = await asyncio.gather(*tasks)

        for username, repos in zip(usernames, results):
            print(f"  → {username} has {len(repos)} public repos\n")

await main()

# %% [markdown]
# ### Exercise: Concurrent repository metrics collector
#
# Core concepts needed: async/await, aiohttp, asyncio.gather(), sessions, headers/auth, rate limiting awareness
#
# Here are utility functions you can use during implementation:

# %%
import aiohttp
import asyncio
import time
from typing import Optional


# Utility function: basic async fetch with error handling
async def fetch_json(session: aiohttp.ClientSession, url: str, headers: Optional[dict] = None) -> dict:
    """
    Fetch JSON data from a URL with basic error handling.

    Args:
        session: aiohttp ClientSession
        url: URL to fetch
        headers: Optional headers dict

    Returns:
        JSON response as dict, or empty dict on error
    """
    try:
        async with session.get(url, headers=headers) as response:
            if response.status == 200:
                return await response.json()
            else:
                print(f"Error fetching {url}: Status {response.status}")
                return {}
    except Exception as e:
        print(f"Exception fetching {url}: {e}")
        return {}


# Example usage:
# async with aiohttp.ClientSession() as session:
#     data = await fetch_json(session, "https://api.github.com/users/torvalds")

# %% [markdown]
# Implement the following async functions to collect and analyze repository metrics:

# %%
import aiohttp
import asyncio
import time

async def fetch_repo_languages(
    session: aiohttp.ClientSession,
    owner: str,
    repo: str,
    headers: dict
) -> dict:
    """
    Fetch the programming languages used in a repository.

    Args:
        session: aiohttp ClientSession
        owner: Repository owner username
        repo: Repository name
        headers: Headers dict with authentication

    Returns:
        Dictionary with language stats, e.g., {"Python": 45230, "JavaScript": 12000}
        Returns empty dict if request fails

    API endpoint: https://api.github.com/repos/{owner}/{repo}/languages
    """

    # Collect languages of repo
    url = f"https://api.github.com/repos/{owner}/{repo}/languages"
    language_list = await fetch_json(session, url, headers)
    print(language_list)
    await language_list


async def analyze_user_repos_async(
    session: aiohttp.ClientSession,
    username: str,
    headers: dict
) -> dict:
    """
    Analyze all public repositories for a user concurrently.

    Steps:
    1. Fetch the user's repositories list
    2. For each repo, fetch its language stats concurrently using asyncio.gather()
    3. Aggregate the data

    Args:
        session: aiohttp ClientSession
        username: GitHub username
        headers: Headers dict with authentication

    Returns:
        Dictionary containing:
        {
            "username": str,
            "total_repos": int,
            "total_languages": dict,  # Aggregated language bytes across all repos
            "repos_analyzed": int,
            "execution_time": float  # Time taken in seconds
        }

    API endpoints:
    - User repos: https://api.github.com/users/{username}/repos
    - Then use fetch_repo_languages() for each repo
    """
    start = time.time()
    url = f"https://api.github.com/users/{username}/repos"

    async with fetch_json(session, url, headers) as response:
        repo_names = [repo["name"] for repo in response]
        total_repos = len(repo_names)
        repo_stats = []
        repo_stats = [fetch_repo_languages(session, username, repo, headers) for repo in repo_names]
        results = await asyncio.gather(*repo_stats)

        total_languages = {}
        for repo_stat in repo_stats:
            total_languages = {**total_languages, **repo_stat}
        repos_analyzed = repo_names.index(repo) + 1
        execution_time : float = time.time() - start
        result_dict = {}
        result_dict.append({username, total_repos, total_languages, repos_analyzed, execution_time})

       # Run stats for all repos concurrently
        repos = [repo_stat['key'] for repo_stat in repo_stats]
        result_dict = await asyncio.gather(*repos)
        print(result_dict)

        await result_dict


async def compare_users(
    session: aiohttp.ClientSession,
    usernames: list[str],
    headers: dict
) -> list[dict]:
    """
    Analyze multiple users concurrently and return their stats.

    Args:
        session: aiohttp ClientSession
        usernames: List of GitHub usernames
        headers: Headers dict with authentication

    Returns:
        List of user analysis results (from analyze_user_repos_async)
        sorted by total_repos in descending order

    Use asyncio.gather() to analyze all users concurrently.
    """
    pass

# %% [markdown]
# Test cases:

# %%
async def run_all_tests():
    print("=" * 70)
    print("CONCURRENT REPOSITORY METRICS COLLECTOR")
    print("=" * 70)
    print()

    # Setup headers
    headers = {
        'Authorization': f'Bearer {github_token}',
        'Accept': 'application/vnd.github.v3+json'
    }

    async with aiohttp.ClientSession() as session:
        # Test 1: fetch_repo_languages
        print("Test 1: fetch_repo_languages")
        print("-" * 70)

        languages = await fetch_repo_languages(session, "torvalds", "linux", headers)

        assert isinstance(languages, dict), "Should return a dictionary"
        assert len(languages) > 0, "Linux repo should have languages"
        assert "C" in languages, "Linux repo should contain C"

        print(f"Linux repository languages: {list(languages.keys())[:5]}...")
        print(f"Total languages found: {len(languages)}")

        for lang, bytes_count in languages.items():
            assert isinstance(bytes_count, int), f"Language byte count should be int, got {type(bytes_count)}"

        print("fetch_repo_languages test passed!\n")

        # Test 2: analyze_user_repos_async
        print("Test 2: analyze_user_repos_async")
        print("-" * 70)

        start_time = time.time()
        analysis = await analyze_user_repos_async(session, "gvanrossum", headers)
        elapsed = time.time() - start_time

        assert isinstance(analysis, dict), "Should return a dictionary"
        assert "username" in analysis, "Should contain 'username'"
        assert "total_repos" in analysis, "Should contain 'total_repos'"
        assert "total_languages" in analysis, "Should contain 'total_languages'"
        assert "repos_analyzed" in analysis, "Should contain 'repos_analyzed'"
        assert "execution_time" in analysis, "Should contain 'execution_time'"

        assert analysis["username"] == "gvanrossum", "Username should match"
        assert analysis["total_repos"] > 0, "Should have some repos"
        assert isinstance(analysis["total_languages"], dict), "Languages should be a dict"
        assert analysis["repos_analyzed"] >= 0, "Should analyze some repos"
        assert analysis["execution_time"] > 0, "Should track execution time"

        print(f"Username: {analysis['username']}")
        print(f"Total repositories: {analysis['total_repos']}")
        print(f"Repositories analyzed: {analysis['repos_analyzed']}")
        print(f"Total languages found: {len(analysis['total_languages'])}")

        # Show top 5 languages by byte count
        if analysis['total_languages']:
            top_languages = sorted(
                analysis['total_languages'].items(),
                key=lambda x: x[1],
                reverse=True
            )[:5]
            print(f"Top languages:")
            for lang, bytes_count in top_languages:
                print(f"  - {lang}: {bytes_count:,} bytes")

        print(f"Execution time: {analysis['execution_time']:.2f}s")
        print(f"(Fetched in {elapsed:.2f}s - should be similar to execution_time)")
        print("analyze_user_repos_async test passed!\n")

        # Test 3: compare_users
        print("Test 3: compare_users")
        print("-" * 70)

        usernames = ["torvalds", "gvanrossum", "kennethreitz"]

        start_time = time.time()
        results = await compare_users(session, usernames, headers)
        elapsed = time.time() - start_time

        # Check structure
        assert isinstance(results, list), "Should return a list"
        assert len(results) == len(usernames), f"Should return {len(usernames)} results"

        # Check all results have required fields
        for result in results:
            assert "username" in result, "Each result should have username"
            assert "total_repos" in result, "Each result should have total_repos"
            assert result["username"] in usernames, "Username should be one we requested"

        # Check sorting (descending by total_repos)
        for i in range(len(results) - 1):
            assert results[i]["total_repos"] >= results[i + 1]["total_repos"], \
                "Results should be sorted by total_repos in descending order"

        print("Concurrent analysis of multiple users:")
        for i, result in enumerate(results, 1):
            top_lang = "N/A"
            if result["total_languages"]:
                top_lang = max(result["total_languages"].items(), key=lambda x: x[1])[0]

            print(f"  {i}. {result['username']}")
            print(f"     Repos: {result['total_repos']}, "
                  f"Languages: {len(result['total_languages'])}, "
                  f"Top: {top_lang}")

        print(f"\nTotal execution time: {elapsed:.2f}s")
        print(f"Average time per user: {elapsed / len(usernames):.2f}s")
        print("compare_users test passed!\n")

        # Test 4: Verify async performance benefit
        print("Test 4: Async performance verification")
        print("-" * 70)

        max_expected_time = max(r["execution_time"] for r in results) * 2

        assert elapsed < max_expected_time, \
            f"Concurrent execution ({elapsed:.2f}s) should be faster than sequential"

        print(f"Concurrent execution: {elapsed:.2f}s")
        print(f"Individual execution times: {[f"{r['execution_time']:.2f}s" for r in results]}")
        print("Async performance benefit confirmed!")
        print("(Concurrent execution is much faster than running sequentially)\n")

        print("=" * 70)
        print("ALL TESTS PASSED")
        print("=" * 70)
        total_repos = sum(r["total_repos"] for r in results)
        all_languages = set()
        for r in results:
            all_languages.update(r["total_languages"].keys())

        print(f"\nAnalyzed {len(usernames)} users with {total_repos} total repositories")
        print(f"Found {len(all_languages)} unique programming languages")
        print(f"Total execution time: {elapsed:.2f}s")

# %%
try:
    await run_all_tests()
except Exception as e:
    print(f"\nTEST FAILED: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ======================================================================
# CONCURRENT REPOSITORY METRICS COLLECTOR
# ======================================================================
#
#
# TEST FAILED: name 'github_token' is not defined
# Traceback (most recent call last):
#   File "/tmp/ipykernel_2547/1256665316.py", line 2, in <cell line: 1>
#     await run_all_tests()
#   File "/tmp/ipykernel_2547/1361505710.py", line 9, in run_all_tests
#     'Authorization': f'Bearer {github_token}',
#                                ^^^^^^^^^^^^
# NameError: name 'github_token' is not defined

# %% [markdown]
# ### Solution

# %%
async def fetch_repo_languages(
    session: aiohttp.ClientSession,
    owner: str,
    repo: str,
    headers: dict
) -> dict:
    """
    Fetch the programming languages used in a repository.

    Args:
        session: aiohttp ClientSession
        owner: Repository owner username
        repo: Repository name
        headers: Headers dict with authentication

    Returns:
        Dictionary with language stats, e.g., {"Python": 45230, "JavaScript": 12000}
        Returns empty dict if request fails

    API endpoint: https://api.github.com/repos/{owner}/{repo}/languages
    """
    url = f"https://api.github.com/repos/{owner}/{repo}/languages"
    return await fetch_json(session, url, headers)


async def analyze_user_repos_async(
    session: aiohttp.ClientSession,
    username: str,
    headers: dict
) -> dict:
    """
    Analyze all public repositories for a user concurrently.

    Steps:
    1. Fetch the user's repositories list
    2. For each repo, fetch its language stats concurrently using asyncio.gather()
    3. Aggregate the data

    Args:
        session: aiohttp ClientSession
        username: GitHub username
        headers: Headers dict with authentication

    Returns:
        Dictionary containing:
        {
            "username": str,
            "total_repos": int,
            "total_languages": dict,  # Aggregated language bytes across all repos
            "repos_analyzed": int,
            "execution_time": float  # Time taken in seconds
        }

    API endpoints:
    - User repos: https://api.github.com/users/{username}/repos
    - Then use fetch_repo_languages() for each repo
    """
    start_time = time.time()

    # Step 1: Fetch user's repositories
    repos_url = f"https://api.github.com/users/{username}/repos"
    repos = await fetch_json(session, repos_url, headers)

    if not repos:
        return {
            "username": username,
            "total_repos": 0,
            "total_languages": {},
            "repos_analyzed": 0,
            "execution_time": time.time() - start_time
        }

    # Step 2: Fetch language stats for all repos concurrently
    language_tasks = [
        fetch_repo_languages(session, username, repo["name"], headers)
        for repo in repos
    ]

    all_languages = await asyncio.gather(*language_tasks)

    # Step 3: Aggregate language data
    total_languages = {}
    repos_analyzed = 0

    for lang_dict in all_languages:
        if lang_dict:  # Only count repos that returned data
            repos_analyzed += 1
            for language, bytes_count in lang_dict.items():
                total_languages[language] = total_languages.get(language, 0) + bytes_count

    return {
        "username": username,
        "total_repos": len(repos),
        "total_languages": total_languages,
        "repos_analyzed": repos_analyzed,
        "execution_time": time.time() - start_time
    }


async def compare_users(
    session: aiohttp.ClientSession,
    usernames: list[str],
    headers: dict
) -> list[dict]:
    """
    Analyze multiple users concurrently and return their stats.

    Args:
        session: aiohttp ClientSession
        usernames: List of GitHub usernames
        headers: Headers dict with authentication

    Returns:
        List of user analysis results (from analyze_user_repos_async)
        sorted by total_repos in descending order

    Use asyncio.gather() to analyze all users concurrently.
    """
    # Create tasks for all users
    tasks = [
        analyze_user_repos_async(session, username, headers)
        for username in usernames
    ]

    # Run all analyses concurrently
    results = await asyncio.gather(*tasks)

    # Sort by total_repos in descending order
    sorted_results = sorted(results, key=lambda x: x["total_repos"], reverse=True)

    return sorted_results
